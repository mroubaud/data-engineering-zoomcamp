# %%
import pandas as pd
from time import time
from sqlalchemy import create_engine

# %%
df = pd.read_csv("../ny_taxi_postgres_data/yellow_tripdata_2021-01.csv", nrows=300)

# %%
df
# Out:
#      VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0           1  2021-01-01 00:30:10   2021-01-01 00:36:12                1
# 1           1  2021-01-01 00:51:20   2021-01-01 00:52:19                1
# 2           1  2021-01-01 00:43:30   2021-01-01 01:11:06                1
# 3           1  2021-01-01 00:15:48   2021-01-01 00:31:01                0
# 4           2  2021-01-01 00:31:49   2021-01-01 00:48:21                1
# ..        ...                  ...                   ...              ...
# 295         2  2021-01-01 00:28:41   2021-01-01 00:43:22                1
# 296         2  2021-01-01 00:49:07   2021-01-01 00:51:44                1
# 297         2  2021-01-01 00:24:52   2021-01-01 00:30:20                3
# 298         2  2021-01-01 00:38:55   2021-01-01 01:21:47                1
# 299         2  2021-01-01 00:39:33   2021-01-01 00:47:49                1
#
#      trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# ...

# %%
print(pd.io.sql.get_schema(df, name="yellow_taxi_data"))
# Out:
# CREATE TABLE "yellow_taxi_data" (
# "VendorID" INTEGER,
#   "tpep_pickup_datetime" TEXT,
#   "tpep_dropoff_datetime" TEXT,
#   "passenger_count" INTEGER,
#   "trip_distance" REAL,
#   "RatecodeID" INTEGER,
#   "store_and_fwd_flag" TEXT,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "payment_type" INTEGER,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "congestion_surcharge" REAL
# )

# %%
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)

# %%
print(pd.io.sql.get_schema(df, name="yellow_taxi_data"))
# Out:
# CREATE TABLE "yellow_taxi_data" (
# "VendorID" INTEGER,
#   "tpep_pickup_datetime" TIMESTAMP,
#   "tpep_dropoff_datetime" TIMESTAMP,
#   "passenger_count" INTEGER,
#   "trip_distance" REAL,
#   "RatecodeID" INTEGER,
#   "store_and_fwd_flag" TEXT,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "payment_type" INTEGER,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "congestion_surcharge" REAL
# )

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
engine.connect()

# %%
print(pd.io.sql.get_schema(df, name="yellow_taxi_data", con=engine))
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	"RatecodeID" BIGINT,
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53)
# )

# %%
df_iter = pd.read_csv("../ny_taxi_postgres_data/yellow_tripdata_2021-01.csv", iterator=True, chunksize=100000)

# %%
df_iter

# %%
df = next(df_iter)

# %%
len(df)
# Out:
# 100000

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2021-01-01 00:30:10   2021-01-01 00:36:12                1
# 1         1  2021-01-01 00:51:20   2021-01-01 00:52:19                1
# 2         1  2021-01-01 00:43:30   2021-01-01 01:11:06                1
# 3         1  2021-01-01 00:15:48   2021-01-01 00:31:01                0
# 4         2  2021-01-01 00:31:49   2021-01-01 00:48:21                1
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.10           1                  N           142            43
# 1           0.20           1                  N           238           151
# 2          14.70           1                  N           132           165
# 3          10.60           1                  N           138           132
# 4           4.94           1                  N            68            33
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
#create sql table with no rows, just the dic
#if table exist it will be replaced for the new one
df.head(n=0).to_sql(name="yellow_taxi_data", con=engine, if_exists="replace")
# Out:
# 0

# %%
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)

# %%
#apppend data to the created table and check how much time it takes
# %time df.to_sql(name="yellow_taxi_data", con=engine, if_exists="append")
# Out:
# CPU times: user 2.02 s, sys: 213 ms, total: 2.24 s
# Wall time: 4.58 s
# 1000

# %%
while True:
    
    #to measure how much time it takes to build the table
    t_start = time()
    
    df = next(df_iter)
    
    df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
    df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
    
    df.to_sql(name="yellow_taxi_data", con=engine, if_exists="append")
    
    #to measure how much time it takes to build the table
    t_end = time()
    
    print("inserted another chunk..., took %.3f second" %(t_end-t_start))
# Out:
# inserted another chunk..., took 5.024 second
# inserted another chunk..., took 4.075 second
# inserted another chunk..., took 4.234 second
# inserted another chunk..., took 4.797 second
# inserted another chunk..., took 4.146 second
# inserted another chunk..., took 4.318 second
# inserted another chunk..., took 4.640 second
# inserted another chunk..., took 4.192 second
# inserted another chunk..., took 4.958 second
# inserted another chunk..., took 4.102 second
# inserted another chunk..., took 4.597 second
# /var/folders/j4/3bcsts1575195393dj3gg_cw0000gn/T/ipykernel_31143/151135663.py:6: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = next(df_iter)
# inserted another chunk..., took 4.803 second
# inserted another chunk..., took 3.485 second
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[33], line 6
# ...

# %%
query = """
SELECT 1 as number;
"""
pd.read_sql(query, con=engine)
# Out:
#    number
# 0       1

# %%
df.to_sql(name="yellow_tripdata_trip", con=engine ,index=False)
# Out:
# 765

# %%
query = """
SELECT * FROM yellow_tripdata_trip LIMIT 10
"""
pd.read_sql(query, con=engine)
# Out:
#   VendorID tpep_pickup_datetime tpep_dropoff_datetime passenger_count  \
# 0     None  2021-01-05 10:38:40   2021-01-05 10:46:20            None
# 1     None  2021-01-05 10:17:14   2021-01-05 10:41:21            None
# 2     None  2021-01-05 10:39:00   2021-01-05 10:46:00            None
# 3     None  2021-01-05 10:05:00   2021-01-05 10:19:00            None
# 4     None  2021-01-05 10:18:08   2021-01-05 10:41:40            None
# 5     None  2021-01-05 10:06:19   2021-01-05 10:26:11            None
# 6     None  2021-01-05 10:10:02   2021-01-05 10:28:14            None
# 7     None  2021-01-05 10:49:03   2021-01-05 11:02:57            None
# 8     None  2021-01-05 10:01:50   2021-01-05 11:01:03            None
# 9     None  2021-01-05 10:43:18   2021-01-05 11:06:16            None
#
#    trip_distance RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           1.30       None               None           170           161
# ...

# %%
# this url contains taxi zone data
# assume we have downloaded the file as "taxi+_zone_lookup.csv"
df_zones = pd.read_csv("taxi+_zone_lookup.csv")

engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

engine.connect()

df_zones.to_sql(name='zones', con=engine, if_exists='replace') # zones is a new table
# Out:
# 265

# %%
from hashlib import sha1

def compute_hash(email):
    return sha1(email.lower().encode('utf-8')).hexdigest()

# %%
compute_hash("matiasroubaud@gmail.com")
# Out:
# 'c0e8d6c2c47b273ea6f8ce3028cabef65a3429e1'

# %%
df = pd.read_csv("./green_tripdata_2019-09.csv")
# Out:
# /var/folders/j4/3bcsts1575195393dj3gg_cw0000gn/T/ipykernel_38694/3065481611.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("./green_tripdata_2019-09.csv")

# %%
df.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0       2.0  2019-09-01 00:10:53   2019-09-01 00:23:46                  N
# 1       2.0  2019-09-01 00:31:22   2019-09-01 00:44:37                  N
# 2       2.0  2019-09-01 00:50:24   2019-09-01 01:03:20                  N
# 3       2.0  2019-09-01 00:27:06   2019-09-01 00:33:22                  N
# 4       2.0  2019-09-01 00:43:23   2019-09-01 00:59:54                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            65           189              5.0           2.00
# 1         1.0            97           225              5.0           3.20
# 2         1.0            37            61              5.0           2.99
# 3         1.0           145           112              1.0           1.73
# 4         1.0           112           198              1.0           3.42
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# ...
