# %% [markdown]
# # **Homework**: Data talks club data engineering zoomcamp Data loading workshop
#
# Hello folks, let's practice what we learned - Loading data with the best practices of data engineering.
#
# Here are the exercises we will do

# %% [markdown]
# # 1. Use a generator
#
# Remember the concept of generator? Let's practice using them to futher our understanding of how they work.
#
# Let's define a generator and then run it as practice.
#
# **Answer the following questions:**
#
# - **Question 1: What is the sum of the outputs of the generator for limit = 5?**
# - **Question 2: What is the 13th number yielded**
#
# I suggest practicing these questions without GPT as the purpose is to further your learning.

# %%
def square_root_generator(limit):
    n = 1
    while n <= limit:
        yield n ** 0.5
        n += 1

# Example usage:
limit = 13
sum = 0

generator = square_root_generator(limit)

for sqrt_value in generator:
    print("number handle", sqrt_value)
    sum = sum + sqrt_value
print("suma total", sum)
# Out:
# number handle 1.0
# number handle 1.4142135623730951
# number handle 1.7320508075688772
# number handle 2.0
# number handle 2.23606797749979
# number handle 2.449489742783178
# number handle 2.6457513110645907
# number handle 2.8284271247461903
# number handle 3.0
# number handle 3.1622776601683795
# number handle 3.3166247903554
# number handle 3.4641016151377544
# number handle 3.605551275463989
# suma total 32.854555867161245

# %% [markdown]
# # 2. Append a generator to a table with existing data
#
#
# Below you have 2 generators. You will be tasked to load them to duckdb and answer some questions from the data
#
# 1. Load the first generator and calculate the sum of ages of all people. Make sure to only load it once.
# 2. Append the second generator to the same table as the first.
# 3. **After correctly appending the data, calculate the sum of all ages of people.**

# %%
def people_1():
    for i in range(1, 6):
        yield {"ID": i, "Name": f"Person_{i}", "Age": 25 + i, "City": "City_A"}

for person in people_1():
    print(person)


def people_2():
    for i in range(3, 9):
        yield {"ID": i, "Name": f"Person_{i}", "Age": 30 + i, "City": "City_B", "Occupation": f"Job_{i}"}


for person in people_2():
    print(person)
# Out:
# {'ID': 1, 'Name': 'Person_1', 'Age': 26, 'City': 'City_A'}
# {'ID': 2, 'Name': 'Person_2', 'Age': 27, 'City': 'City_A'}
# {'ID': 3, 'Name': 'Person_3', 'Age': 28, 'City': 'City_A'}
# {'ID': 4, 'Name': 'Person_4', 'Age': 29, 'City': 'City_A'}
# {'ID': 5, 'Name': 'Person_5', 'Age': 30, 'City': 'City_A'}
# {'ID': 3, 'Name': 'Person_3', 'Age': 33, 'City': 'City_B', 'Occupation': 'Job_3'}
# {'ID': 4, 'Name': 'Person_4', 'Age': 34, 'City': 'City_B', 'Occupation': 'Job_4'}
# {'ID': 5, 'Name': 'Person_5', 'Age': 35, 'City': 'City_B', 'Occupation': 'Job_5'}
# {'ID': 6, 'Name': 'Person_6', 'Age': 36, 'City': 'City_B', 'Occupation': 'Job_6'}
# {'ID': 7, 'Name': 'Person_7', 'Age': 37, 'City': 'City_B', 'Occupation': 'Job_7'}
# {'ID': 8, 'Name': 'Person_8', 'Age': 38, 'City': 'City_B', 'Occupation': 'Job_8'}

# %%
# !pip install dlt[duckdb] # Install dlt with all the necessary DuckDB dependencies
# !pip install dlt
import dlt
import duckdb

# %%
pipeline = dlt.pipeline(destination='duckdb', dataset_name='people')

info = pipeline.run(people_1,
										table_name="people_table",
										write_disposition="replace",
                    primary_key="ID")

print(info)

# show the outcome

conn = duckdb.connect(f"{pipeline.pipeline_name}.duckdb")

# let's see the tables
conn.sql(f"SET search_path = '{pipeline.dataset_name}'")
print('Loaded tables: ')
display(conn.sql("show tables"))


print("\n\n\n People 1 table below:")
full_people_table = conn.sql("SELECT * FROM people_table").df()
display(full_people_table)

print("\n\n\n People 1 age sum")
age_sum = conn.sql("SELECT SUM(age) FROM people_table").df()
display(age_sum)
# Out:
# Pipeline dlt_colab_kernel_launcher load step completed in 0.18 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset people
# The duckdb destination used duckdb:////content/dlt_colab_kernel_launcher.duckdb location to store data
# Load package 1707822262.2408156 is LOADED and contains no failed jobs
# Loaded tables:
# ┌─────────────────────┐
# │        name         │
# │       varchar       │
# ├─────────────────────┤
# │ _dlt_loads          │
# │ _dlt_pipeline_state │
# │ _dlt_version        │
# │ people_table        │
# └─────────────────────┘
#  People 1 table below: Note the times are properly typed
#    id      name  age    city        _dlt_load_id         _dlt_id occupation
# 0   1  Person_1   26  City_A  1707822262.2408156  i8BkDCQotOZmVw       None
# 1   2  Person_2   27  City_A  1707822262.2408156  qpJQGw2mAzoJsg       None
# 2   3  Person_3   28  City_A  1707822262.2408156  pyhSYJH27UD3dg       None
# ...

# %%
info = pipeline.run(people_2,
										table_name="people_table",
										write_disposition="append",
                    primary_key="ID")

print(info)

# show the outcome

conn = duckdb.connect(f"{pipeline.pipeline_name}.duckdb")

# let's see the tables
conn.sql(f"SET search_path = '{pipeline.dataset_name}'")
print('Loaded tables: ')
display(conn.sql("show tables"))


print("\n\n\n People 1 + People 2 appended table below:")
full_people_table = conn.sql("SELECT * FROM people_table").df()
display(full_people_table)
# Out:
# Pipeline dlt_colab_kernel_launcher load step completed in 0.23 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset people
# The duckdb destination used duckdb:////content/dlt_colab_kernel_launcher.duckdb location to store data
# Load package 1707822267.484923 is LOADED and contains no failed jobs
# Loaded tables:
# ┌─────────────────────┐
# │        name         │
# │       varchar       │
# ├─────────────────────┤
# │ _dlt_loads          │
# │ _dlt_pipeline_state │
# │ _dlt_version        │
# │ people_table        │
# └─────────────────────┘
#  People 1 + People 2 appended table below: Note the times are properly typed
#     id      name  age    city        _dlt_load_id         _dlt_id occupation
# 0    1  Person_1   26  City_A  1707822262.2408156  i8BkDCQotOZmVw       None
# 1    2  Person_2   27  City_A  1707822262.2408156  qpJQGw2mAzoJsg       None
# 2    3  Person_3   28  City_A  1707822262.2408156  pyhSYJH27UD3dg       None
# ...

# %%
print("\n\n\n People 1 + People 2 age sum")
age_sum = conn.sql("SELECT SUM(age) FROM people_table").df()
display(age_sum)
# Out:
#  People 1 + People 2 age sum
#    sum(age)
# 0     353.0

# %% [markdown]
# # 3. Merge a generator
#
# Re-use the generators from Exercise 2.
#
# A table's primary key needs to be created from the start, so load your data to a new table with primary key ID.
#
# Load your first generator first, and then load the second one with merge. Since they have overlapping IDs, some of the records from the first load should be replaced by the ones from the second load.
#
# After loading, you should have a total of 8 records, and ID 3 should have age 33.
#
# Question: **Calculate the sum of ages of all the people loaded as described above.**

# %%
pipeline = dlt.pipeline(destination='duckdb', dataset_name='people')

info = pipeline.run(people_1,
										table_name="people_table",
										write_disposition="replace",
                    primary_key="ID")

print(info)

# show the outcome

conn = duckdb.connect(f"{pipeline.pipeline_name}.duckdb")

# let's see the tables
conn.sql(f"SET search_path = '{pipeline.dataset_name}'")
print('Loaded tables: ')
display(conn.sql("show tables"))


print("\n\n\n People 1 table below:")
full_people_table = conn.sql("SELECT * FROM people_table").df()
display(full_people_table)

print("\n\n\n People 1 age sum")
age_sum = conn.sql("SELECT SUM(age) FROM people_table").df()
display(age_sum)
# Out:
# Pipeline dlt_colab_kernel_launcher load step completed in 0.18 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset people
# The duckdb destination used duckdb:////content/dlt_colab_kernel_launcher.duckdb location to store data
# Load package 1707822382.4376717 is LOADED and contains no failed jobs
# Loaded tables:
# ┌─────────────────────┐
# │        name         │
# │       varchar       │
# ├─────────────────────┤
# │ _dlt_loads          │
# │ _dlt_pipeline_state │
# │ _dlt_version        │
# │ people_table        │
# └─────────────────────┘
#  People 1 table below: Note the times are properly typed
#    id      name  age    city        _dlt_load_id         _dlt_id occupation
# 0   1  Person_1   26  City_A  1707822382.4376717  fCiGn8fvEol9Qw       None
# 1   2  Person_2   27  City_A  1707822382.4376717  nz/D9PbKLun1fw       None
# 2   3  Person_3   28  City_A  1707822382.4376717  3snKIIpxVcRsBQ       None
# ...

# %%
info = pipeline.run(people_2,
										table_name="people_table",
										write_disposition="merge",
                    primary_key="ID")

print(info)

# show the outcome

conn = duckdb.connect(f"{pipeline.pipeline_name}.duckdb")

# let's see the tables
conn.sql(f"SET search_path = '{pipeline.dataset_name}'")
print('Loaded tables: ')
display(conn.sql("show tables"))


print("\n\n\n People 1 merged with People 2 table below:")
full_people_table = conn.sql("SELECT * FROM people_table").df()
display(full_people_table)

print("\n\n\n People 1 merged with People 2 age sum")
age_sum = conn.sql("SELECT SUM(age) FROM people_table").df()
display(age_sum)
# Out:
# Pipeline dlt_colab_kernel_launcher load step completed in 0.42 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset people
# The duckdb destination used duckdb:////content/dlt_colab_kernel_launcher.duckdb location to store data
# Load package 1707822480.5224297 is LOADED and contains no failed jobs
# Loaded tables:
# ┌─────────────────────┐
# │        name         │
# │       varchar       │
# ├─────────────────────┤
# │ _dlt_loads          │
# │ _dlt_pipeline_state │
# │ _dlt_version        │
# │ people_table        │
# └─────────────────────┘
#  People 1 merged with People 2 table below:
#    id      name  age    city        _dlt_load_id         _dlt_id occupation
# 0   1  Person_1   26  City_A  1707822382.4376717  fCiGn8fvEol9Qw       None
# 1   2  Person_2   27  City_A  1707822382.4376717  nz/D9PbKLun1fw       None
# 2   8  Person_8   38  City_B  1707822480.5224297  w/5TtGmYZElSCQ      Job_8
# ...

# %% [markdown]
# # Solution: First make sure that the following modules are installed:

# %%
#Install the dependencies
# %%capture
# !pip install dlt[duckdb]

# %% [markdown]
# Questions? difficulties? We are here to help.
# - DTC data engineering course channel: https://datatalks-club.slack.com/archives/C01FABYF2RG
# - dlt's DTC cohort channel: https://dlthub-community.slack.com/archives/C06GAEX2VNX
